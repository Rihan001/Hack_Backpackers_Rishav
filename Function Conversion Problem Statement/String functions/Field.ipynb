# %%
# number by default as 1
def getField(str1,delimeter,occurance, number):
  i = 1
  listField = []
  for i in range(number):
    listField.insert(split(str1, delimeter).[occurance])
  for str in listField:
    str2 += str
    str2 += ','
  return str2
